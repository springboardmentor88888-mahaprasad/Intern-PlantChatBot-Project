# %%
print("Detected classes:", len(class_folders))

for cls in class_folders:
    cls_path=os.path.join(source_dataset, cls)

    images= (
             glob(cls_path + "/*.jpg")  +
             glob(cls_path + "/*.jpeg") +
             glob(cls_path + "/*.png")

            )

if not images:
      continue

train_imgs, val_imgs = train_test_split(
    images, test_size=0.2, random_state=42

)

os.makedirs(os.path.join(train_dir, cls), exist_ok=True)
os.makedirs(os.path.join(val_dir, cls), exist_ok=True)

for ing in train_imgs:
    shutil.copy(img, os.path.join(train_dir, cls))

for ing in val_imgs:
    shutil.copy(img, os.path.join(val_dir, cls))

print(" Dataset split completed successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-798555407.py in <cell line: 0>()
# ----> 1 print("Detected classes:", len(class_folders))
#       2
#       3 for cls in class_folders:
#       4     cls_path=os.path.join(source_dataset, cls)
#       5
#
# NameError: name 'class_folders' is not defined

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models

# %%
import torch
import torch.nn as nn
from torchvision import models

device="cuda"

#Load pretrained model
model=models.resnet50(weights="IMAGENETIK_V1")

#Number of classes
num_classes=5 #< change this!

#Replace final FC layer
model.fc=nn. Linear(model.fc.in_features, num_classes)

model=model.to(device)
print(model)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-607124834.py in <cell line: 0>()
#       6
#       7 #Load pretrained model
# ----> 8 model=models.resnet50(weights="IMAGENETIK_V1")
#       9
#      10 #Number of classes
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py in wrapper(*args, **kwargs)
#     140             kwargs.update(keyword_only_kwargs)
#     141
# --> 142         return fn(*args, **kwargs)
#     143
#     144     return wrapper
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py in inner_wrapper(*args, **kwargs)
#     226                 kwargs[weights_param] = default_weights_arg
#     227
# --> 228             return builder(*args, **kwargs)
#     229
#     230         return inner_wrapper
#
# ...

# %%
raw_dir="/content/plantvillage_data/plantvillage/PlantVillage"
print("Exists:", os.path.exists(raw_dir))
print("Content count:", len(os.listdir(raw_dir)) if os.path.exists(raw_dir) else "NA")
print("Sample folders:", os.listdir(raw_dir) [:5] if os.path.exists(raw_dir) else "NA")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2896370452.py in <cell line: 0>()
#       1 raw_dir="/content/plantvillage_data/plantvillage/PlantVillage"
# ----> 2 print("Exists:", os.path.exists(raw_dir))
#       3 print("Content count:", len(os.listdir(raw_dir)) if os.path.exists(raw_dir) else "NA")
#       4 print("Sample folders:", os.listdir(raw_dir) [:5] if os.path.exists(raw_dir) else "NA")
#
# NameError: name 'os' is not defined

# %%
import os
print("Content root:", os.listdir("/content"))
# Out:
# Content root: ['.config', 'sample_data']

# %%
print("Does/content/data exist?", os.path.exists("/content/data"))

if os.path.exists("/content/data"):
  print("Inside/content/data:", os.listdir("/content/data"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-628668134.py in <cell line: 0>()
# ----> 1 print("Does/content/data exist?", os.path.exists("/content/data"))
#       2
#       3 if os.path.exists("/content/data"):
#       4   print("Inside/content/data:", os.listdir("/content/data"))
#
# NameError: name 'os' is not defined

# %%
# !mkdir -p /content/data/train_dir
# !mkdir -p /content/data/val

# %%
import os
print(os.listdir("/content/data"))
# Out:
# ['train_dir', 'val']

# %%
SPLIT DATASET(MANDATORY AGAIN)
# Out:
#   File "/tmp/ipython-input-1034060648.py", line 1
#     SPLIT DATASET(MANDATORY AGAIN)
#           ^
# SyntaxError: invalid syntax

# %%
import os, shutil, random

raw_dir= "/content/plantvillage/data/plantvillage/Plantvillage"
train_dir="/content/data/trave"
val_dir="/content/data/val"

split_ratio = 0.9

for cls in os.listdir(raw_dir):
    cls_path=os.path.join(raw_dir, cls)
    if not os.path.isdir(cls_path):
      continue

images=os.listdir(cls_path)
if len(images)==0:
     continue

random.shuffle(images)
split=int(len(images)=split_ratio)

os.makedirs(os.path.join(train_dir, cls), exist _ok=True)
os.makedirs(os.path.join(val_dir, cls), exist_ok=True)

for img in images[: split]:
# Out:
#   File "/tmp/ipython-input-4106974275.py", line 19
#     split=int(len(images)=split_ratio)
#               ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
import os

train_dir="/content/data/train"
val_dir="/content/data/val"

print("Train folder exists:", os.path.exists(train_dir))
print("Val folder exists:", os.path.exists(val_dir))

print("Train classes:", os.listdir(train_dir))
print("Val classes:", os.listdir(val_dir))
# Out:
# Train folder exists: False
# Val folder exists: True
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3131645180.py in <cell line: 0>()
#       7 print("Val folder exists:", os.path.exists(val_dir))
#       8
# ----> 9 print("Train classes:", os.listdir(train_dir))
#      10 print("Val classes:", os.listdir(val_dir))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data/train'

# %%
from torchvision import datasets

train_dataset datasets. ImageFolder(
    root=train_dir,
    transform=train_transform
)

val_dataset=datasets. ImageFolder(
   root=val_dir,
   transform=val_transform
)


print("Train images:", len(train_dataset))
print("Val images:", len(val_dataset))
print("Number of classes:", len(train_dataset.classes))
print("Class names:", train_dataset.classes)
# Out:
#   File "/tmp/ipython-input-3818257279.py", line 3
#     train_dataset datasets. ImageFolder(
#                   ^
# SyntaxError: invalid syntax

# %%
from google.colab import files
files.download("/content/plant_disease_resnet50.pth")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-92586320.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download("/content/plant_disease_resnet50.pth")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/plant_disease_resnet50.pth
